# %%
import pandas as pd
import time
import sklearn as sk 
from sklearn import preprocessing
# %pylab
# Out:
# Using matplotlib backend: MacOSX
# Populating the interactive namespace from numpy and matplotlib

# %%
t1 = time.time()
print('Loading database ...')
df = pd.read_hdf('Database/all_data_comp.h5','table')
print('Time to load database:', time.time()-t1)
# Out:
# Loading database ...
# Time to load database: 3.5605101585388184

# %%
headers = list(df)
print('Number of headers:', len(headers))
# Out:
# Number of headers: 2563

# %%
# write all headers to a CSV file

headers = open('Database/headers.csv','w')
a = list(df)
for item in a:
    headers.write('\n' + item)
headers.close()

# %%
X = np.array([1,3,20,-4]).reshape(-1,1)
#X = X.reshape(-1,1)
normaliser = preprocessing.MinMaxScaler()
normaliser.fit_transform(X)
# Out:
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:444: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# array([[ 0.20833333],
#        [ 0.29166667],
#        [ 1.        ],
#        [ 0.        ]])

# %%
preprocessing.normalize(X)
# Out:
# array([[ 1.],
#        [ 1.],
#        [ 1.],
#        [-1.]])

# %%
df.tail()
# Out:
#                      AE LO SEPAR1 ALARM:7103:-:Average:900  \
# Time
# 2015-02-01 08:00:00                                    0.0
# 2015-02-01 08:15:00                                    0.0
# 2015-02-01 08:30:00                                    0.0
# 2015-02-01 08:45:00                                    0.0
# 2015-02-01 09:00:00                                    0.0
#
#                      AE LO SEPAR1 RUN:71034:nan:Average:900  \
# Time
# 2015-02-01 08:00:00                                     0.0
# 2015-02-01 08:15:00                                     0.0
# 2015-02-01 08:30:00                                     0.0
# 2015-02-01 08:45:00                                     0.0
# 2015-02-01 09:00:00                                     0.0
#
#                      AE LO SEPAR1 RUN:71034:nan:Raw data:3600  \
# Time
# 2015-02-01 08:00:00                                       NaN
# 2015-02-01 08:15:00                                       NaN
# ...

# %%
df.describe()
# Out:
#        AE LO SEPAR1 ALARM:7103:-:Average:900  \
# count                            8869.000000
# mean                               -0.002180
# std                                 0.041464
# min                                -1.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 0.000000
#
#        AE LO SEPAR1 RUN:71034:nan:Average:900  \
# count                             8869.000000
# mean                                 1.953606
# std                                  0.298477
# min                                  0.000000
# 25%                                  2.000000
# 50%                                  2.000000
# 75%                                  2.000000
# max                                  2.000000
#
#        AE LO SEPAR1 RUN:71034:nan:Raw data:3600  \
# count                                673.000000
# ...

# %%
headers
# Out:
# ['AE LO SEPAR1 ALARM:7103:-:Average:900',
#  'AE LO SEPAR1 RUN:71034:nan:Average:900',
#  'AE LO SEPAR1 RUN:71034:nan:Raw data:3600',
#  'AE LO SEPAR2  RUN:71044:nan:Average:900',
#  'AE LO SEPAR2  RUN:71044:nan:Raw data:3600',
#  'AE LO SEPAR2 ALARM:7104:-:Average:900',
#  'AE SCR 2CFC20 ALARM:6854:-:Average:900',
#  'AE SCR 2CFC20 ALARM:6854:-:Raw data:3600',
#  'AE SCR CBD10 230V IS:6858:-:Average:900',
#  'AE SCR CBD10 230V IS:6858:-:Raw data:3600',
#  'AE SCR CBD10 24V ISO:6857:-:Average:900',
#  'AE SCR CBD10 24V ISO:6857:-:Raw data:3600',
#  'AE SCR CBD10 FUSE:6856:-:Average:900',
#  'AE SCR CBD10 FUSE:6856:-:Raw data:3600',
#  'AE SCR CBD10 WARNING:6853:-:Average:900',
#  'AE SCR CBD10 WARNING:6853:-:Raw data:3600',
#  'AE SCR CFC20 230V IS:6868:-:Average:900',
#  'AE SCR CFC20 230V IS:6868:-:Raw data:3600',
#  'AE SCR CFC20 AIR CON:6874:-:Average:900',
#  'AE SCR CFC20 AIR CON:6874:-:Raw data:3600',
#  'AE SCR CFC20 ANALYS:6867:-:Average:900',
# ...
