# %% [markdown]
# # Script for merging all Excel-data from M/S Birka into one HDF5-database
#
# The Pandas-library is used for both reading, writing and sorting the data.

# %%
import pandas as pd
import glob

csv_data_path = 'csv/'
xls_data_path = 'original/'
database_path = 'database/'

xlsfiles = glob.glob(xls_data_path + '*.xls')

# %% [markdown]
# # Clean Excel files, make .CSV
#
# Cleaning of the raw Excel files. Reading a .CSV file is much faster than a .XLS. So the first step is to clean and filter the data, and resave them into CSV files.
#
# The data which is fetched from the ship is in exported with their database tool to Excel-97 files. As it wasn't possible to export more than a certain amount of rows (<65k) as well as the file being to large with to many columns, the data was
# exported in several batches. As this was done manually, by clicking thousands of small tick-boxes, this unfortunally meant that some data was overlapped both in time-series as well as duplicate data columns in different files. The data in the first 10 rows of the Excel-files
# contained meta-data about each data point which needed to be extracted and put togehter into one header. Some of the Excel-files also
# contained non ASCII-characters which also needed to be filtered out.

# %%
####
####
# Clean up csv
# Make CSV-files and clean up headers.
####
####


# As there are non uni-code characters in the original headers file it needs be fixed..
# The following function was found here:
# http://stackoverflow.com/questions/20078816/replace-non-ascii-characters-with-a-single-space
# And replaces all non unicode chars with a space

def remove_non_ascii(text):
    return ''.join([i if ord(i) < 128 else ' ' for i in text])

for i in range(len(xlsfiles)):
    df = pd.DataFrame()
    df2 = pd.DataFrame()

    print('Processing: '+str(xlsfiles[i].split('/')[-1].split('.')[0]))
    df = pd.read_excel(xlsfiles[i],index_col=0)
    df.index.name = 'Time'

    headers = list(df)
    headers_new = list()

    # And now extract the relevant meta-data in the first couple of rows.
    # Make a new list of headers in the file. Using ':' as a split.


    for head in headers:

        name = str(df[head].iloc[0])
        id_nr = str(head.split('.')[2].split(':')[1])
        unit = str(df[head].iloc[1])
        data_type = str(df[head].iloc[5])
        sample_interval = str(df[head].iloc[8])

        headers_new.append(str(name+':'+id_nr+':'+unit+':'+data_type+':'+sample_interval))

    for n in range(len(headers_new)):
        series = df[headers[n]].ix[13:]
        df2[remove_non_ascii(headers_new[n])] = series


    # Save in .csv format.
    df2.to_csv(csv_data_path + xlsfiles[i].split('/')[-1].split('.')[0] + '.csv')
    #df2.to_excel(csv_data_path + xlsfiles[i].split('/')[-1].split('.')[0] + '.xls')

    # Clean up memory
    del df2
    del df
    print(str(i+1) + ' done of ' + str(len(xlsfiles)))

print('All done!')

# %% [markdown]
# # Crate database for everything in 15-min frequency
#
# All data is gathered into one master Pandas DataFrame. The append-function puts the the DataFrame in the bottom but keeps track
# of the columns. The resample-function is applied.

# %%
data_freq = '15min'

all_data=pd.DataFrame()
csvfiles = glob.glob(csv_data_path + '*.csv')

for i in range(len(csvfiles)):
    df = pd.DataFrame()
    df_out = pd.DataFrame()
    print('Processing: '+str(csvfiles[i].split('/')[-1].split('.')[0]))
    df = pd.read_csv(csvfiles[i],header=0,index_col=0,dtype='a')
    df.index = pd.to_datetime(df.index)
    
    print('Resampling: '+str(csvfiles[i].split('/')[-1].split('.')[0]))
    
    for n in range(len(list(df))):
        df_out[list(df)[n]] = pd.to_numeric(df[list(df)[n]],errors='ignore')
    
    print('Appending: '+str(csvfiles[i].split('/')[-1].split('.')[0]))
    all_data = all_data.append(df_out).resample(data_freq).mean()
    
    del df # Clean up memory
    del df_out # Clean up memory
    print(str(i+1) + ' done of ' + str(len(csvfiles)))


print('Saving database...\n')
all_data.to_hdf(database_path + 'all_data_comp.h5','table',complevel=9,complib='blosc') # compressed version

print('All done!')
# Out:
# Processing: ship speed outside temp
# Resampling: ship speed outside temp
# Appending: ship speed outside temp
# 1 done of 52
# Processing: prio4-2201-3652
# Resampling: prio4-2201-3652
# Appending: prio4-2201-3652
# 2 done of 52
# Processing: 3922-4372
# Resampling: 3922-4372
# Appending: 3922-4372
# 3 done of 52
# Processing: 2506-2946
# Resampling: 2506-2946
# Appending: 2506-2946
# 4 done of 52
# Processing: 1-1161-2203
# Resampling: 1-1161-2203
# Appending: 1-1161-2203
# 5 done of 52
# Processing: 1 week 6502
# Resampling: 1 week 6502
# Appending: 1 week 6502
# 6 done of 52
# Processing: dec jan 15min -1748
# Resampling: dec jan 15min -1748
# Appending: dec jan 15min -1748
# 7 done of 52
# Processing: scr me ae
# Resampling: scr me ae
# Appending: scr me ae
# 8 done of 52
# Processing: 12mo 15m int fuel rack ship speed ae me etc
# Resampling: 12mo 15m int fuel rack ship speed ae me etc
# Appending: 12mo 15m int fuel rack ship speed ae me etc
# 9 done of 52
# Processing: prio3
# Resampling: prio3
# Appending: prio3
# 10 done of 52
# Processing: 5-6437-40006
# Resampling: 5-6437-40006
# Appending: 5-6437-40006
# 11 done of 52
# Processing: 1year_mean_motor_fuel rack_etc
# Resampling: 1year_mean_motor_fuel rack_etc
# Appending: 1year_mean_motor_fuel rack_etc
# 12 done of 52
# Processing: prio2
# Resampling: prio2
# Appending: prio2
# 13 done of 52
# Processing: 4914-64154
# Resampling: 4914-64154
# Appending: 4914-64154
# 14 done of 52
# Processing: 3mo weather
# Resampling: 3mo weather
# Appending: 3mo weather
# 15 done of 52
# Processing: 1w egbo speed weather
# Resampling: 1w egbo speed weather
# Appending: 1w egbo speed weather
# 16 done of 52
# Processing: 4 weeks main 6303-
# Resampling: 4 weeks main 6303-
# Appending: 4 weeks main 6303-
# 17 done of 52
# Processing: 3-3364-4641
# Resampling: 3-3364-4641
# Appending: 3-3364-4641
# 18 done of 52
# Processing: nov dec 1min 1749-2505
# Resampling: nov dec 1min 1749-2505
# Appending: nov dec 1min 1749-2505
# 19 done of 52
# Processing: 30004-3756
# Resampling: 30004-3756
# Appending: 30004-3756
# 20 done of 52
# Processing: 10004-1748
# Resampling: 10004-1748
# Appending: 10004-1748
# 21 done of 52
# Processing: 4w electrical ae1-4
# Resampling: 4w electrical ae1-4
# Appending: 4w electrical ae1-4
# 22 done of 52
# Processing: dec jan 1min 1749-2505
# Resampling: dec jan 1min 1749-2505
# Appending: dec jan 1min 1749-2505
# 23 done of 52
# Processing: 4w egbo circ pump temp
# Resampling: 4w egbo circ pump temp
# Appending: 4w egbo circ pump temp
# 24 done of 52
# Processing: 4W MOTOR FUEL RACK SPEED AE
# Resampling: 4W MOTOR FUEL RACK SPEED AE
# Appending: 4W MOTOR FUEL RACK SPEED AE
# 25 done of 52
# Processing: 4w egbo me ae fuel rack
# Resampling: 4w egbo me ae fuel rack
# Appending: 4w egbo me ae fuel rack
# 26 done of 52
# Processing: 1749-2347
# Resampling: 1749-2347
# Appending: 1749-2347
# 27 done of 52
# Processing: 4374-4913
# Resampling: 4374-4913
# Appending: 4374-4913
# 28 done of 52
# Processing: 3591-3921
# Resampling: 3591-3921
# Appending: 3591-3921
# 29 done of 52
# Processing: 2-2252-3347
# Resampling: 2-2252-3347
# Appending: 2-2252-3347
# 30 done of 52
# Processing: nov-dec 1min -1748
# Resampling: nov-dec 1min -1748
# Appending: nov-dec 1min -1748
# 31 done of 52
# Processing: 4w fuel rack ship speed me ae speed
# Resampling: 4w fuel rack ship speed me ae speed
# Appending: 4w fuel rack ship speed me ae speed
# 32 done of 52
# Processing: dec-jan 1min -1748
# Resampling: dec-jan 1min -1748
# Appending: dec-jan 1min -1748
# 33 done of 52
# Processing: 1 week 6502-6303
# Resampling: 1 week 6502-6303
# Appending: 1 week 6502-6303
# 34 done of 52
# Processing: 4-4644-6429
# Resampling: 4-4644-6429
# Appending: 4-4644-6429
# 35 done of 52
# Processing: 4w sw lt ht pumps temp
# Resampling: 4w sw lt ht pumps temp
# Appending: 4w sw lt ht pumps temp
# 36 done of 52
# Processing: ME 1-4 CA
# Resampling: ME 1-4 CA
# Appending: ME 1-4 CA
# 37 done of 52
# Processing: prio4-3701-end
# Resampling: prio4-3701-end
# Appending: prio4-3701-end
# 38 done of 52
# Processing: 6442-7913 end
# Resampling: 6442-7913 end
# Appending: 6442-7913 end
# 39 done of 52
# Processing: 1w me2-4
# Resampling: 1w me2-4
# Appending: 1w me2-4
# 40 done of 52
# Processing: 4w fuel rack pos speed me ae
# Resampling: 4w fuel rack pos speed me ae
# Appending: 4w fuel rack pos speed me ae
# 41 done of 52
# Processing: 2684-30004
# Resampling: 2684-30004
# Appending: 2684-30004
# 42 done of 52
# Processing: 4w fuel oil tank
# Resampling: 4w fuel oil tank
# Appending: 4w fuel oil tank
# 43 done of 52
# Processing: AE 1-4 CA
# Resampling: AE 1-4 CA
# Appending: AE 1-4 CA
# 44 done of 52
# Processing: 12mo 15min interval fuel oil tank
# Resampling: 12mo 15min interval fuel oil tank
# Appending: 12mo 15min interval fuel oil tank
# 45 done of 52
# Processing: 1 year 15m int
# Resampling: 1 year 15m int
# Appending: 1 year 15m int
# 46 done of 52
# Processing: prio4-1101-2112
# Resampling: prio4-1101-2112
# Appending: prio4-1101-2112
# 47 done of 52
# Processing: 1w me1
# Resampling: 1w me1
# Appending: 1w me1
# 48 done of 52
# Processing: nov jan 15min 1749-2505
# Resampling: nov jan 15min 1749-2505
# Appending: nov jan 15min 1749-2505
# 49 done of 52
# Processing: 4w egbo speed weather
# Resampling: 4w egbo speed weather
# Appending: 4w egbo speed weather
# 50 done of 52
# Processing: 2347-2683
# Resampling: 2347-2683
# Appending: 2347-2683
# 51 done of 52
# Processing: 4w fo cons me ae run time
# Resampling: 4w fo cons me ae run time
# Appending: 4w fo cons me ae run time
# 52 done of 52
# Saving database...
#
# All done!

# %% [markdown]
# # Create a database 1 min interval
#
# Some parts of the data is in 1-min interval. All data which are logged in 15-min interval will be filled with Nan
# between each 15-min point. This can be handled later on, but we don't loose accuracy.

# %%
data_freq = '1min'
all_data=pd.DataFrame()
csvfiles = glob.glob(csv_data_path + '*.csv')

for i in range(len(csvfiles)):
    df = pd.DataFrame()
    df_out = pd.DataFrame()
    print('Processing: '+str(csvfiles[i].split('/')[-1].split('.')[0]))
    df = pd.read_csv(csvfiles[i],header=0,index_col=0,dtype='a')
    df.index = pd.to_datetime(df.index)
    
    print('Resampling: '+str(csvfiles[i].split('/')[-1].split('.')[0]))
    
    for n in range(len(list(df))):
        df_out[list(df)[n]] = pd.to_numeric(df[list(df)[n]],errors='ignore')
    
    print('Appending: '+str(csvfiles[i].split('/')[-1].split('.')[0]))
    all_data = all_data.append(df_out).resample(data_freq).mean()
    
    del df # Clean up memory
    del df_out # Clean up memory
    print(str(i+1) + ' done of ' + str(len(csvfiles)))


print('Saving database...\n')
all_data.to_hdf(database_path + 'all_data_1min_comp.h5','table',complevel=9,complib='blosc') # compressed version

print('All done!')
# Out:
# Processing: ship speed outside temp
# Resampling: ship speed outside temp
# Appending: ship speed outside temp
# 1 done of 52
# Processing: prio4-2201-3652
# Resampling: prio4-2201-3652
# Appending: prio4-2201-3652
# 2 done of 52
# Processing: 3922-4372
# Resampling: 3922-4372
# Appending: 3922-4372
# 3 done of 52
# Processing: 2506-2946
# Resampling: 2506-2946
# Appending: 2506-2946
# 4 done of 52
# Processing: 1-1161-2203
# Resampling: 1-1161-2203
# Appending: 1-1161-2203
# 5 done of 52
# Processing: 1 week 6502
# Resampling: 1 week 6502
# Appending: 1 week 6502
# 6 done of 52
# Processing: dec jan 15min -1748
# Resampling: dec jan 15min -1748
# Appending: dec jan 15min -1748
# 7 done of 52
# Processing: scr me ae
# Resampling: scr me ae
# Appending: scr me ae
# 8 done of 52
# Processing: 12mo 15m int fuel rack ship speed ae me etc
# Resampling: 12mo 15m int fuel rack ship speed ae me etc
# Appending: 12mo 15m int fuel rack ship speed ae me etc
# 9 done of 52
# Processing: prio3
# Resampling: prio3
# Appending: prio3
# 10 done of 52
# Processing: 5-6437-40006
# Resampling: 5-6437-40006
# Appending: 5-6437-40006
# 11 done of 52
# Processing: 1year_mean_motor_fuel rack_etc
# Resampling: 1year_mean_motor_fuel rack_etc
# Appending: 1year_mean_motor_fuel rack_etc
# 12 done of 52
# Processing: prio2
# Resampling: prio2
# Appending: prio2
# 13 done of 52
# Processing: 4914-64154
# Resampling: 4914-64154
# Appending: 4914-64154
# 14 done of 52
# Processing: 3mo weather
# Resampling: 3mo weather
# Appending: 3mo weather
# 15 done of 52
# Processing: 1w egbo speed weather
# Resampling: 1w egbo speed weather
# Appending: 1w egbo speed weather
# 16 done of 52
# Processing: 4 weeks main 6303-
# Resampling: 4 weeks main 6303-
# Appending: 4 weeks main 6303-
# 17 done of 52
# Processing: 3-3364-4641
# Resampling: 3-3364-4641
# Appending: 3-3364-4641
# 18 done of 52
# Processing: nov dec 1min 1749-2505
# Resampling: nov dec 1min 1749-2505
# Appending: nov dec 1min 1749-2505
# 19 done of 52
# Processing: 30004-3756
# Resampling: 30004-3756
# Appending: 30004-3756
# 20 done of 52
# Processing: 10004-1748
# Resampling: 10004-1748
# Appending: 10004-1748
# 21 done of 52
# Processing: 4w electrical ae1-4
# Resampling: 4w electrical ae1-4
# Appending: 4w electrical ae1-4
# 22 done of 52
# Processing: dec jan 1min 1749-2505
# Resampling: dec jan 1min 1749-2505
# Appending: dec jan 1min 1749-2505
# 23 done of 52
# Processing: 4w egbo circ pump temp
# Resampling: 4w egbo circ pump temp
# Appending: 4w egbo circ pump temp
# 24 done of 52
# Processing: 4W MOTOR FUEL RACK SPEED AE
# Resampling: 4W MOTOR FUEL RACK SPEED AE
# Appending: 4W MOTOR FUEL RACK SPEED AE
# 25 done of 52
# Processing: 4w egbo me ae fuel rack
# Resampling: 4w egbo me ae fuel rack
# Appending: 4w egbo me ae fuel rack
# 26 done of 52
# Processing: 1749-2347
# Resampling: 1749-2347
# Appending: 1749-2347
# 27 done of 52
# Processing: 4374-4913
# Resampling: 4374-4913
# Appending: 4374-4913
# 28 done of 52
# Processing: 3591-3921
# Resampling: 3591-3921
# Appending: 3591-3921
# 29 done of 52
# Processing: 2-2252-3347
# Resampling: 2-2252-3347
# Appending: 2-2252-3347
# 30 done of 52
# Processing: nov-dec 1min -1748
# Resampling: nov-dec 1min -1748
# Appending: nov-dec 1min -1748
# 31 done of 52
# Processing: 4w fuel rack ship speed me ae speed
# Resampling: 4w fuel rack ship speed me ae speed
# Appending: 4w fuel rack ship speed me ae speed
# 32 done of 52
# Processing: dec-jan 1min -1748
# Resampling: dec-jan 1min -1748
# Appending: dec-jan 1min -1748
# 33 done of 52
# Processing: 1 week 6502-6303
# Resampling: 1 week 6502-6303
# Appending: 1 week 6502-6303
# 34 done of 52
# Processing: 4-4644-6429
# Resampling: 4-4644-6429
# Appending: 4-4644-6429
# 35 done of 52
# Processing: 4w sw lt ht pumps temp
# Resampling: 4w sw lt ht pumps temp
# Appending: 4w sw lt ht pumps temp
# 36 done of 52
# Processing: ME 1-4 CA
# Resampling: ME 1-4 CA
# Appending: ME 1-4 CA
# 37 done of 52
# Processing: prio4-3701-end
# Resampling: prio4-3701-end
# Appending: prio4-3701-end
# 38 done of 52
# Processing: 6442-7913 end
# Resampling: 6442-7913 end
# Appending: 6442-7913 end
# 39 done of 52
# Processing: 1w me2-4
# Resampling: 1w me2-4
# Appending: 1w me2-4
# 40 done of 52
# Processing: 4w fuel rack pos speed me ae
# Resampling: 4w fuel rack pos speed me ae
# Appending: 4w fuel rack pos speed me ae
# 41 done of 52
# Processing: 2684-30004
# Resampling: 2684-30004
# Appending: 2684-30004
# 42 done of 52
# Processing: 4w fuel oil tank
# Resampling: 4w fuel oil tank
# Appending: 4w fuel oil tank
# 43 done of 52
# Processing: AE 1-4 CA
# Resampling: AE 1-4 CA
# Appending: AE 1-4 CA
# 44 done of 52
# Processing: 12mo 15min interval fuel oil tank
# Resampling: 12mo 15min interval fuel oil tank
# Appending: 12mo 15min interval fuel oil tank
# 45 done of 52
# Processing: 1 year 15m int
# Resampling: 1 year 15m int
# Appending: 1 year 15m int
# 46 done of 52
# Processing: prio4-1101-2112
# Resampling: prio4-1101-2112
# Appending: prio4-1101-2112
# 47 done of 52
# Processing: 1w me1
# Resampling: 1w me1
# Appending: 1w me1
# 48 done of 52
# Processing: nov jan 15min 1749-2505
# Resampling: nov jan 15min 1749-2505
# Appending: nov jan 15min 1749-2505
# 49 done of 52
# Processing: 4w egbo speed weather
# Resampling: 4w egbo speed weather
# Appending: 4w egbo speed weather
# 50 done of 52
# Processing: 2347-2683
# Resampling: 2347-2683
# Appending: 2347-2683
# 51 done of 52
# Processing: 4w fo cons me ae run time
# Resampling: 4w fo cons me ae run time
# Appending: 4w fo cons me ae run time
# 52 done of 52
# Saving database...
#
# All done!
